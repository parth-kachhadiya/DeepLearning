# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
X, Y = make_moons(n_samples=250, noise=0.05, random_state=42)

# %%
plt.scatter(X[:,0], X[:,1], c=Y, s=100)
plt.show()

# %%
model = Sequential()

model.add(Dense(10, activation='sigmoid', input_dim=2))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
old_weights = model.get_weights()[0]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2,
                                                    random_state=42)

# %%
history = model.fit(x_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.4932 - loss: 0.7355
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4728 - loss: 0.7351
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4547 - loss: 0.7330
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4785 - loss: 0.7158
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5394 - loss: 0.6919
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5350 - loss: 0.6916
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5062 - loss: 0.6971
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5248 - loss: 0.6924
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4888 - loss: 0.6974
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5374 - loss: 0.6902
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5060 - loss: 0.6937
# Epoch 12/200
# ...

# %%
new_weights = model.get_weights()[0]

# %%
learning_rate = model.optimizer.get_config()["learning_rate"]
learning_rate
# Out:
# 0.0010000000474974513

# %%
gradients = (old_weights - new_weights) / learning_rate

# %%
percent_change = abs(100 * (old_weights - new_weights) / old_weights)

# %%
gradients
# Out:
# array([[  -7.582962,   53.942738,  -41.263935,   72.14528 ,  -40.172733,
#          -77.87905 ,  153.27649 , -260.509   ,  -33.774494, -132.56161 ],
#        [   6.84008 ,  -48.68692 ,   38.5893  ,  -65.27901 ,   30.319927,
#           61.731514, -128.08173 ,  227.31213 ,   29.78164 ,  109.80802 ]],
#       dtype=float32)

# %%
percent_change
# Out:
# array([[ 1.1586974,  7.743056 ,  6.9306164, 11.977975 , 26.677822 ,
#         48.503345 , 56.294106 , 73.65301  ,  6.2359486, 37.345802 ],
#        [ 2.1889968,  7.3976445, 10.446939 , 12.297541 ,  6.7244945,
#          9.662684 , 22.173136 , 32.889793 ,  4.2474303, 21.358154 ]],
#       dtype=float32)

# %%
old_weights
# Out:
# array([[-0.65443856, -0.69665956, -0.59538627,  0.6023162 , -0.15058476,
#          0.1605643 , -0.27227807,  0.35369772, -0.5416096 , -0.35495722],
#        [-0.31247556, -0.6581409 ,  0.36938375, -0.5308298 ,  0.45088786,
#         -0.6388651 ,  0.5776438 , -0.6911328 , -0.7011684 ,  0.51412696]],
#       dtype=float32)

# %%
new_weights
# Out:
# array([[-0.6468556 , -0.7506023 , -0.5541223 ,  0.5301709 , -0.11041202,
#          0.23844336, -0.42555457,  0.61420673, -0.5078351 , -0.2223956 ],
#        [-0.31931564, -0.609454  ,  0.33079445, -0.46555078,  0.42056793,
#         -0.70059663,  0.70572555, -0.91844493, -0.73095006,  0.40431893]],
#       dtype=float32)

# %% [markdown]
# ---
# # Solution
# ## 1. Reduce model complexity
# ## 2. Use 'ReLU' activation function

# %%
model_2 = Sequential()

model_2.add(Dense(10, activation='relu', input_dim=2))
model_2.add(Dense(10, activation='relu'))
model_2.add(Dense(10, activation='relu'))
model_2.add(Dense(1, activation='sigmoid'))

# %%
model_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
old_weights_2 = model_2.get_weights()[0]

# %%
model_2.fit(x_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2068 - loss: 0.7223
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1861 - loss: 0.7164
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1772 - loss: 0.7082
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1912 - loss: 0.7015
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3538 - loss: 0.6970
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4515 - loss: 0.6941
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5447 - loss: 0.6883
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6187 - loss: 0.6839
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6673 - loss: 0.6789
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6575 - loss: 0.6734
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6897 - loss: 0.6705
# Epoch 12/200
# ...

# %%
new_weights_2 = model_2.get_weights()[0]

# %%
learning_rate_2 = model_2.optimizer.get_config()["learning_rate"]
learning_rate_2
# Out:
# 0.0010000000474974513

# %%
gradients_2 = (old_weights_2 - new_weights_2) / learning_rate_2

# %%
percent_change_2 = abs(100 * (old_weights_2 - new_weights_2) / old_weights_2)

# %%
gradients_2
# Out:
# array([[-221.68636 , -297.49863 ,  499.81216 ,  149.8906  , -210.21019 ,
#          150.69868 ,  541.6219  , -124.31877 ,  712.71954 ,  -82.94514 ],
#        [ 127.75117 ,  329.05124 , -540.4328  , -472.535   ,  221.62245 ,
#         -405.2934  , -624.42883 , -146.43454 ,  -59.176746,  330.7445  ]],
#       dtype=float32)

# %%
percent_change_2
# Out:
# array([[  76.26305 ,   42.594368,  124.52676 ,   22.294165,   39.26488 ,
#           33.49191 ,  106.13134 ,   25.105959,  194.20612 ,   43.87184 ],
#        [  55.10648 ,   79.02299 ,  137.02614 , 1075.5219  ,   63.21835 ,
#           57.92657 ,   92.25257 ,   39.104214,   34.286167,   53.852406]],
#       dtype=float32)

# %%
old_weights_2
# Out:
# array([[ 0.2906865 ,  0.698446  , -0.40136933, -0.6723311 ,  0.53536445,
#          0.44995552, -0.51033175,  0.49517637, -0.3669913 ,  0.18906236],
#        [-0.23182604,  0.41639942, -0.39440125, -0.04393542, -0.3505667 ,
#          0.6996675 , -0.6768688 ,  0.37447256, -0.17259657,  0.6141686 ]],
#       dtype=float32)

# %%
new_weights_2
# Out:
# array([[ 0.51237285,  0.9959446 , -0.9011815 , -0.8222217 ,  0.74557465,
#          0.29925683, -1.0519537 ,  0.61949515, -1.0797108 ,  0.2720075 ],
#        [-0.3595772 ,  0.08734818,  0.14603157,  0.4285996 , -0.57218915,
#          1.1049609 , -0.05243994,  0.5209071 , -0.11341982,  0.28342405]],
#       dtype=float32)
